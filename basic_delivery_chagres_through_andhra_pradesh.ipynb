# %%
#package delivery cost based on location and total amount
total=int(input("enter the amount for the item"))
state="Andhrapradesh"
district=input("enter the name of the district")
if state=="Andhrapradesh" and district=="srikakulam":
  if total<=150:
    print("cost of delivery is 50rs")
  elif total>150 and total==500:
    print("cost of delivery is 45rs")
  elif total>500 and total<1200:
    print("cost of delivery is 40rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="vizayanagaram":
  if total<=150:
    print("cost of delivery is 40rs")
  elif total>150 and total==500:
    print("cost of delivery is 35rs")
  elif total>500 and total<1200:
    print("cost of delivery is 30rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="vishakapatnam":
  if total<=150:
    print("cost of delivery is 50rs")
  elif total>150 and total==500:
    print("cost of delivery is 45rs")
  elif total>500 and total<1200:
    print("cost of delivery is 30rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="East Godavari":
  if total<=150:
    print("cost of delivery is 60rs")
  elif total>150 and total==500:
    print("cost of delivery is 55rs")
  elif total>500 and total<1200:
    print("cost of delivery is 40rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="West Godavari":
  if total<=150:
    print("cost of delivery is 60rs")
  elif total>150 and total==500:
    print("cost of delivery is 55rs")
  elif total>500 and total<1200:
    print("cost of delivery is 50rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="Krishna":
  if total<=150:
    print("cost of delivery is 70rs")
  elif total>150 and total==500:
    print("cost of delivery is 65rs")
  elif total>500 and total<1200:
    print("cost of delivery is 50rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="guntur":
  if total<=150:
    print("cost of delivery is 50rs")
  elif total>150 and total==500:
    print("cost of delivery is 45rs")
  elif total>500 and total<1200:
    print("cost of delivery is 40rs")
  elif total>1200:
    print("delivery is free of cost")

if state=="Andhrapradesh" and district=="kurnool":
  if total<=150:
    print("cost of delivery is 80rs")
  elif total>150 and total==500:
    print("cost of delivery is 75rs")
  elif total>500 and total<1200:
    print("cost of delivery is 60rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="Anantapuram":
  if total<=150:
    print("cost of delivery is 60rs")
  elif total>150 and total==500:
    print("cost of delivery is 55rs")
  elif total>500 and total<1200:
    print("cost of delivery is 50rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="vijayawada":
  if total<=150:
    print("cost of delivery is 50rs")
  elif total>150 and total==500:
    print("cost of delivery is 45rs")
  elif total>500 and total<1200:
    print("cost of delivery is 40rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="Prakasham":
  if total<=150:
    print("cost of delivery is 80rs")
  elif total>150 and total==500:
    print("cost of delivery is 75rs")
  elif total>500 and total<1200:
    print("cost of delivery is 60rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="Chittor":
  if total<=150:
    print("cost of delivery is 80rs")
  elif total>150 and total==500:
    print("cost of delivery is 75rs")
  elif total>500 and total<1200:
    print("cost of delivery is 60rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="Nellore":
  if total<=150:
    print("cost of delivery is 60rs")
  elif total>150 and total==500:
    print("cost of delivery is 55rs")
  elif total>500 and total<1200:
    print("cost of delivery is 50rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="kadapa":
  if total<=150:
    print("cost of delivery is 80rs")
  elif total>150 and total==500:
    print("cost of delivery is 75rs")
  elif total>500 and total<1200:
    print("cost of delivery is 60rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="YSR district":
  if total<=150:
    print("cost of delivery is 90rs")
  elif total>150 and total==500:
    print("cost of delivery is 85rs")
  elif total>500 and total<1200:
    print("cost of delivery is 70rs")
  elif total>1200:
    print("delivery is free of cost")
if state=="Andhrapradesh" and district=="Eluru":
  if total<=150:
    print("cost of delivery is 80rs")
  elif total>150 and total==500:
    print("cost of delivery is 75rs")
  elif total>500 and total<1200:
    print("cost of delivery is 60rs")
  elif total>1200:
    print("delivery is free of cost")
# Out:
# enter the amount for the item150
# enter the name of the districtsrikakulam
# cost of delivery is 50rs
